# %%
import gym
import matplotlib.pyplot as plt
import numpy as np

env = gym.make("CartPole-v0")
env.reset()

i_arr = range(2500)
rewards = np.zeros(2500)
velocities = np.zeros(2500)
power = np.zeros(2500)

for i in range(2500):
    env.render()
    newState, rew, _, _ = env.step(env.action_space.sample())
    velocities[i] = np.sqrt(newState[7]**2 + newState[8]**2)
    if (velocities[i] > 2.428371031919227):
        velocities[i] = 2.428371031919227
    power[i] = 2.448*(np.sum(np.abs(newState[9:])))
    if (power[i] > 50 or np.isnan(power[i])):
        power[i] = 50
    rewards[i] = rew

env.close()

cots = power/velocities

for i in range(2500):
    if (cots[i] > 50 or np.isnan(cots[i])):
        cots[i] = 50

print("Average cot")
print(np.average(cots))

plt.figure()
plt.plot(i_arr, cots)
plt.show()

print("Average power")
print(np.average(power))

plt.figure() 
plt.plot(i_arr, power)
plt.show()

# plt.figure()
# plt.plot(i_arr, rewards)
# plt.show()
# Out:
# /Users/shravannageswaran/Desktop/Harvard_CSE_2019-2020/First Semester/CS 249r/centipede_project/coolpraject/RL-centipede/gym/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# /Users/shravannageswaran/Desktop/Harvard_CSE_2019-2020/First Semester/CS 249r/centipede_project/coolpraject/RL-centipede/gym/gym/envs/classic_control/functions.py:238: RuntimeWarning: overflow encountered in matmul
#   xi[i,:] = np.matmul(np.matmul(np.transpose(u), np.matmul(np.transpose(Jn), Jn)), u) + np.matmul(np.matmul(rcn,dJn), u)
# /Users/shravannageswaran/Desktop/Harvard_CSE_2019-2020/First Semester/CS 249r/centipede_project/coolpraject/RL-centipede/gym/gym/envs/classic_control/functions.py:238: RuntimeWarning: invalid value encountered in matmul
#   xi[i,:] = np.matmul(np.matmul(np.transpose(u), np.matmul(np.transpose(Jn), Jn)), u) + np.matmul(np.matmul(rcn,dJn), u)
# /Users/shravannageswaran/Desktop/Harvard_CSE_2019-2020/First Semester/CS 249r/centipede_project/coolpraject/RL-centipede/gym/gym/envs/classic_control/functions.py:265: RuntimeWarning: overflow encountered in matmul
#   lbda = -np.linalg.inv(Jc @ MInv @ np.transpose(Jc)) @ (Jc @ MInv @ gamma + xi)  # constraint forces
# /Users/shravannageswaran/Desktop/Harvard_CSE_2019-2020/First Semester/CS 249r/centipede_project/coolpraject/RL-centipede/gym/gym/envs/classic_control/functions.py:265: RuntimeWarning: invalid value encountered in matmul
#   lbda = -np.linalg.inv(Jc @ MInv @ np.transpose(Jc)) @ (Jc @ MInv @ gamma + xi)  # constraint forces
# /Users/shravannageswaran/Desktop/Harvard_CSE_2019-2020/First Semester/CS 249r/centipede_project/coolpraject/RL-centipede/gym/gym/envs/classic_control/functions.py:194: RuntimeWarning: overflow encountered in matmul
#   h = np.matmul(ADTrig, u)  # matrix of gyroscopic accelerations
# /Users/shravannageswaran/Desktop/Harvard_CSE_2019-2020/First Semester/CS 249r/centipede_project/coolpraject/RL-centipede/gym/gym/envs/classic_control/functions.py:194: RuntimeWarning: invalid value encountered in matmul
#   h = np.matmul(ADTrig, u)  # matrix of gyroscopic accelerations
# /Users/shravannageswaran/Desktop/Harvard_CSE_2019-2020/First Semester/CS 249r/centipede_project/coolpraject/RL-centipede/gym/gym/envs/classic_control/functions.py:245: RuntimeWarning: overflow encountered in power
#   rcnn = np.sign(cInfo[i,1])*action*rcn/(np.linalg.norm(np.power(rcn,2)))
# /Users/shravannageswaran/Desktop/Harvard_CSE_2019-2020/First Semester/CS 249r/centipede_project/coolpraject/RL-centipede/gym/gym/envs/classic_control/functions.py:238: RuntimeWarning: invalid value encountered in add
#   xi[i,:] = np.matmul(np.matmul(np.transpose(u), np.matmul(np.transpose(Jn), Jn)), u) + np.matmul(np.matmul(rcn,dJn), u)
# Stopping here!
# [[2.         1.57079633 3.03827862 2.79334273 0.9621363  0.28304024]
#  [5.         1.57079633 2.74386373 4.97648472 3.48363744 1.76740563]]
# [[ 7.23207251e+174]
#  [ 2.93528260e+176]
#  [-1.56640803e+177]
#  [-2.57453987e+177]
#  [ 7.96964944e+177]
#  [-2.07909476e+178]
#  [ 3.14681487e+177]
#  [             nan]
#  [             nan]
#  [             nan]
#  [             nan]
#  [             nan]
#  [             nan]
#  [             nan]]
# [[-9.38512080e-008  3.22451198e-002  1.13575179e+001  1.11436121e+001
#    1.14155440e+001  1.17006165e+001  1.17845552e+001  2.00000000e+000
#    2.00000000e+000 -1.35640612e+001  4.95859834e+001  4.04560888e+001
#   -5.14683074e+001 -9.31604764e+001]
#  [ 3.99990615e-003  3.62451198e-002  1.13303897e+001  1.12427841e+001
#    1.14964561e+001  1.15976799e+001  1.15982342e+001  7.66021845e+000
#  [-9.49905230e+004 -9.48971204e+004 -1.78968315e+005  2.26626660e+005
#   -2.15425858e+003 -1.85739412e+005  5.39228130e+005  2.30936621e+012
#    2.66956828e+012  2.09310631e+013 -2.01576928e+013 -4.86489550e+013
#    5.77758160e+013 -6.98603055e+013]
#  [ 4.61863743e+009  5.33904165e+009  4.18619472e+010 -4.03151590e+010
#   -9.72979121e+010  1.15551446e+011 -1.39720072e+011 -1.37804248e+023
#   -1.29726949e+023  4.32626614e+023  4.92410278e+023  1.04942807e+024
#    7.86788920e+024 -7.01805973e+024]
#  [-2.75608496e+020 -2.59453899e+020  8.65253228e+020  9.84820556e+020
#    2.09885613e+021  1.57357784e+022 -1.40361195e+022  4.79952538e+045
#    1.43523489e+045 -6.10591960e+045  2.52320933e+046 -4.01452042e+046
#    2.57914141e+046  7.69030367e+046]
#  [ 9.59905075e+042  2.87046978e+042 -1.22118392e+043  5.04641866e+043
#   -8.02904084e+043  5.15828282e+043  1.53806073e+044  1.28856106e+089
#    1.34010731e+089 -9.46788234e+089  3.94336020e+089 -8.76924351e+089
#   -2.95465052e+090 -4.56415609e+090]
#  [ 2.57712213e+086  2.68021462e+086 -1.89357647e+087  7.88672041e+086
#   -1.75384870e+087 -5.90930104e+087 -9.12831219e+087  7.23207251e+174
#    2.93528260e+176 -1.56640803e+177 -2.57453987e+177  7.96964944e+177
#   -2.07909476e+178  3.14681487e+177]
#  [ 1.44641450e+172  5.87056520e+173 -3.13281606e+174 -5.14907975e+174
#    1.59392989e+175 -4.15818953e+175  6.29362974e+174              nan
#                nan              nan              nan              nan
#                nan              nan]]
# continue
# //anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:16: RuntimeWarning: overflow encountered in double_scalars
#   app.launch_new_instance()
# /Users/shravannageswaran/Desktop/Harvard_CSE_2019-2020/First Semester/CS 249r/centipede_project/coolpraject/RL-centipede/gym/gym/envs/classic_control/reward.py:9: RuntimeWarning: overflow encountered in square
#   velocity = np.sqrt(pow(u[0], 2) + pow(u[1], 2))
# Average cot
# 5.6451351362429545
# //anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:26: RuntimeWarning: divide by zero encountered in true_divide
# Average power
# 5.80612131913568

# %%
import gym

from baselines import deepq 
from stable_baselines.common.policies import MlpPolicy
from stable_baselines.common.vec_env import DummyVecEnv
from stable_baselines import PPO2


# def callback(lcl, _glb):
#     # stop training if reward exceeds 199
#     is_solved = lcl['t'] > 30 and sum(lcl['episode_rewards'][-101:-1]) / 100 >= 30
#     return is_solved

# #centipede model (called cartpole)
# env = gym.make("CartPole-v0")
# act = deepq.learn(
#     env,
#     network='mlp',
#     lr=1e-3,
#     total_timesteps=100,
#     buffer_size=50,
#     callback=callback
# )
# print("Saving model to cartpole_model.pkl")
# act.save("cartpole_model.pkl")

print("started")
env = gym.make("CartPole-v0")
env = DummyVecEnv([lambda: env])
model = PPO2(MlpPolicy, env, verbose=1)
model.learn(total_timesteps=100)
# Out:
# started
# WARNING:tensorflow:From //anaconda3/lib/python3.7/site-packages/stable_baselines/common/tf_util.py:57: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From //anaconda3/lib/python3.7/site-packages/stable_baselines/common/tf_util.py:66: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From //anaconda3/lib/python3.7/site-packages/stable_baselines/common/policies.py:115: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# WARNING:tensorflow:From //anaconda3/lib/python3.7/site-packages/stable_baselines/common/input.py:25: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From //anaconda3/lib/python3.7/site-packages/stable_baselines/common/policies.py:562: flatten (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.flatten instead.
# /Users/shravannageswaran/Desktop/Harvard_CSE_2019-2020/First Semester/CS 249r/centipede_project/coolpraject/RL-centipede/gym/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# WARNING:tensorflow:From //anaconda3/lib/python3.7/site-packages/stable_baselines/a2c/utils.py:156: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
#
# WARNING:tensorflow:From //anaconda3/lib/python3.7/site-packages/stable_baselines/ppo2/ppo2.py:193: The name tf.summary.scalar is deprecated. Please use tf.compat.v1.summary.scalar instead.
#
# WARNING:tensorflow:From //anaconda3/lib/python3.7/site-packages/tensorflow/python/ops/math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From //anaconda3/lib/python3.7/site-packages/stable_baselines/ppo2/ppo2.py:209: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
#
# WARNING:tensorflow:From //anaconda3/lib/python3.7/site-packages/stable_baselines/ppo2/ppo2.py:245: The name tf.summary.merge_all is deprecated. Please use tf.compat.v1.summary.merge_all instead.

# %%
print("Made it here")
import numpy as np
import matplotlib.pyplot as plt

i_arr = range(2500)
rewards = np.zeros(2500)
velocities = np.zeros(2500)
cots = np.zeros(2500)
power = np.zeros(2500)

env = gym.make("CartPole-v0")
obs = env.reset()
for i in range(2500):
    action, _states = model.predict(obs)
    obs, rew, dones, info = env.step(action)
    env.render()
    velocities[i] = np.sqrt(obs[7]**2 + obs[8]**2)
    if (velocities[i] > 2.428371031919227):
        velocities[i] = 2.428371031919227
    power[i] = 2.448*(np.sum(np.abs(obs[9:])))
    if (power[i] > 50 or np.isnan(power[i])):
        power[i] = 50
    rewards[i] = rew
env.close()

cots = power/velocities

for i in range(2500):
    if (cots[i] > 50 or np.isnan(cots[i])):
        cots[i] = 50

print("Average cot")
print(np.average(cots))

plt.figure()
plt.plot(i_arr, cots)
plt.show()

print("Average power")
print(np.average(power))

plt.figure() 
plt.plot(i_arr, power)
plt.show()

# plt.figure()
# plt.plot(i_arr, rewards)
# plt.show()
# Out:
# Made it here
# /Users/shravannageswaran/Desktop/Harvard_CSE_2019-2020/First Semester/CS 249r/centipede_project/coolpraject/RL-centipede/gym/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# /Users/shravannageswaran/Desktop/Harvard_CSE_2019-2020/First Semester/CS 249r/centipede_project/coolpraject/RL-centipede/gym/gym/envs/classic_control/functions.py:194: RuntimeWarning: overflow encountered in matmul
#   h = np.matmul(ADTrig, u)  # matrix of gyroscopic accelerations
# /Users/shravannageswaran/Desktop/Harvard_CSE_2019-2020/First Semester/CS 249r/centipede_project/coolpraject/RL-centipede/gym/gym/envs/classic_control/functions.py:194: RuntimeWarning: invalid value encountered in matmul
#   h = np.matmul(ADTrig, u)  # matrix of gyroscopic accelerations
# /Users/shravannageswaran/Desktop/Harvard_CSE_2019-2020/First Semester/CS 249r/centipede_project/coolpraject/RL-centipede/gym/gym/envs/classic_control/functions.py:238: RuntimeWarning: overflow encountered in matmul
#   xi[i,:] = np.matmul(np.matmul(np.transpose(u), np.matmul(np.transpose(Jn), Jn)), u) + np.matmul(np.matmul(rcn,dJn), u)
# /Users/shravannageswaran/Desktop/Harvard_CSE_2019-2020/First Semester/CS 249r/centipede_project/coolpraject/RL-centipede/gym/gym/envs/classic_control/functions.py:238: RuntimeWarning: invalid value encountered in matmul
#   xi[i,:] = np.matmul(np.matmul(np.transpose(u), np.matmul(np.transpose(Jn), Jn)), u) + np.matmul(np.matmul(rcn,dJn), u)
# /Users/shravannageswaran/Desktop/Harvard_CSE_2019-2020/First Semester/CS 249r/centipede_project/coolpraject/RL-centipede/gym/gym/envs/classic_control/functions.py:245: RuntimeWarning: overflow encountered in power
#   rcnn = np.sign(cInfo[i,1])*action*rcn/(np.linalg.norm(np.power(rcn,2)))
# /Users/shravannageswaran/Desktop/Harvard_CSE_2019-2020/First Semester/CS 249r/centipede_project/coolpraject/RL-centipede/gym/gym/envs/classic_control/functions.py:265: RuntimeWarning: overflow encountered in matmul
#   lbda = -np.linalg.inv(Jc @ MInv @ np.transpose(Jc)) @ (Jc @ MInv @ gamma + xi)  # constraint forces
# /Users/shravannageswaran/Desktop/Harvard_CSE_2019-2020/First Semester/CS 249r/centipede_project/coolpraject/RL-centipede/gym/gym/envs/classic_control/functions.py:265: RuntimeWarning: invalid value encountered in matmul
#   lbda = -np.linalg.inv(Jc @ MInv @ np.transpose(Jc)) @ (Jc @ MInv @ gamma + xi)  # constraint forces
# Stopping here!
# [[ 1.00000000e+00 -1.57079633e+00  1.55355923e+00  3.68598070e+00
#    1.27947808e-07  7.11752868e-03]
#  [ 4.00000000e+00 -1.57079633e+00  2.93187550e+00  4.00686780e+00
#    7.78109779e-01 -2.42164350e+00]]
# [[-6.04738327e+152]
#  [ 2.71158536e+153]
#  [ 1.03793918e+154]
#  [-2.20883106e+154]
#  [ 3.36204297e+154]
#  [-1.36906659e+154]
#  [ 8.28757077e+153]
#  [             nan]
#  [             nan]
#  [             nan]
#  [             nan]
#  [             nan]
#  [             nan]
#  [             nan]]
# [[ 1.27947808e-007  7.11752868e-003  3.69410660e+000  1.52577725e+001
#   -2.26007594e+000  2.23575483e+001 -1.07717510e+001 -7.46516886e+003
#    2.00000000e+000  3.49003173e+004 -6.49562497e+004 -6.21597190e+004
#    1.04336849e+005 -7.70935262e+003]
#  [-1.49303376e+001  1.11175287e-002  7.34947413e+001 -1.14654727e+002
#   -1.26579514e+002  2.31031245e+002 -2.61904562e+001 -4.48697188e+005
#    2.16628029e+005 -1.02770585e+007  1.51958414e+007 -1.86798531e+007
#    1.08996937e+007  2.20359318e+007]
#  [-9.12324713e+002  4.33267175e+002 -2.04806222e+004  3.02770281e+004
#   -3.74862857e+004  2.20304187e+004  4.40456732e+004  7.81475646e+010
#   -3.50403925e+011  7.69328046e+011  9.54604491e+011 -1.96949762e+012
#    1.59196094e+012 -8.46653634e+011]
#    3.93705363e+003 -3.23243719e+004  3.38766303e+004 -3.71331969e+004
#    1.60086254e+004 -3.45607445e+004]
#  [-1.52218151e+001  9.20638608e+000 -6.49555532e+001  6.47860664e+001
#   -7.95999487e+001  2.47919628e+001 -5.46652161e+001  3.24727687e+005
#    3.70742297e+005 -1.23322439e+006 -3.59271336e+006 -1.48164981e+006
#   -1.45717880e+006  7.67519331e+005]
#  [ 6.34233559e+002  7.50690980e+002 -2.53140434e+003 -7.12064065e+003
#   -3.04289956e+003 -2.88956564e+003  1.48037345e+003 -7.80038253e+009
#   -1.37525060e+009 -3.16060999e+010 -9.64909988e+009  2.42325402e+009
#    7.13705924e+009  6.22929017e+009]
#  [-1.56001308e+007 -2.74975050e+006 -6.32147313e+007 -1.93053204e+007
#    4.84346514e+006  1.42712289e+007  1.24600607e+007 -3.73090265e+017
#    2.90121520e+017  5.36969803e+017  6.05566001e+017 -3.24491157e+016
#   -2.52529676e+016  6.01958628e+015]
#  [-7.46180546e+014  5.80243038e+014  1.07393954e+015  1.21113198e+015
#   -6.48982266e+013 -5.05059210e+013  1.20391850e+013  1.39765552e+032
#    1.74978450e+032 -1.07795059e+033  4.82693123e+032  3.15061036e+032
#   -1.71898369e+032 -2.47881503e+032]
#  [ 2.79531104e+029  3.49956900e+029 -2.15590119e+030  9.65386245e+029
#    6.30122073e+029 -3.43796739e+029 -4.95763007e+029 -6.00527180e+062
#    2.91544414e+062  1.01173518e+063 -1.20146917e+063 -6.38173655e+062
#   -4.39004213e+062  1.43425088e+062]
#  [-1.20105436e+060  5.83088828e+059  2.02347036e+060 -2.40293834e+060
#   -1.27634731e+060 -8.78008425e+059  2.86850177e+059 -3.31566325e+122
#   -6.26352283e+122  3.92779143e+123 -1.59083649e+123  1.56362209e+123
#   -3.99923418e+122  2.62732142e+122]
#  [-6.63132649e+119 -1.25270457e+120  7.85558286e+120 -3.18167297e+120
#    3.12724419e+120 -7.99846837e+119  5.25464284e+119 -7.30060320e+243
#   -7.91872483e+243  1.80738929e+243 -1.25996779e+243 -6.77587567e+243
#   -5.94103064e+243  5.02917886e+242]
#  [-1.46012064e+241 -1.58374497e+241  3.61477858e+240 -2.51993558e+240
#   -1.35517513e+241 -1.18820613e+241  1.00583577e+240              nan
#                nan              nan              nan              nan
#                nan              nan]]
# continue
# //anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:17: RuntimeWarning: overflow encountered in double_scalars
# /Users/shravannageswaran/Desktop/Harvard_CSE_2019-2020/First Semester/CS 249r/centipede_project/coolpraject/RL-centipede/gym/gym/envs/classic_control/reward.py:9: RuntimeWarning: overflow encountered in square
#   velocity = np.sqrt(pow(u[0], 2) + pow(u[1], 2))
# /Users/shravannageswaran/Desktop/Harvard_CSE_2019-2020/First Semester/CS 249r/centipede_project/coolpraject/RL-centipede/gym/gym/envs/classic_control/functions.py:238: RuntimeWarning: invalid value encountered in add
#   xi[i,:] = np.matmul(np.matmul(np.transpose(u), np.matmul(np.transpose(Jn), Jn)), u) + np.matmul(np.matmul(rcn,dJn), u)
# close
# Average cot
# 5.1499927929646
# //anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:26: RuntimeWarning: divide by zero encountered in true_divide
# //anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:26: RuntimeWarning: invalid value encountered in true_divide
# Average power
# 7.075379144697622

# %%
print("Getting there, now let's run the actions")
import gym

env = gym.make("CartPole-v0")
env.reset()
for _ in range(100):
    env.render()
    env.step(env.action_space.sample())
env.close()
